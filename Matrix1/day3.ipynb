# %%
# !pip install datadotworld
# !pip install datadotworld[pandas]
# Out:
# Collecting datadotworld
#   Downloading datadotworld-1.8.0-py2.py3-none-any.whl (423 kB)
#      |████████████████████████████████| 423 kB 4.3 MB/s
# Collecting datapackage<2.0a,>=1.6.2
#   Downloading datapackage-1.15.2-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 2.1 MB/s
# Requirement already satisfied: python-dateutil<3.0a,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld) (2.8.2)
# Requirement already satisfied: urllib3<2.0a,>=1.15 in /usr/local/lib/python3.7/dist-packages (from datadotworld) (1.24.3)
# Requirement already satisfied: certifi>=2017.04.17 in /usr/local/lib/python3.7/dist-packages (from datadotworld) (2021.10.8)
# Requirement already satisfied: requests<3.0a,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld) (2.23.0)
# Collecting configparser<4.0a,>=3.5.0
#   Downloading configparser-3.8.1-py2.py3-none-any.whl (22 kB)
# Collecting click<7.0a,>=6.0
#   Downloading click-6.7-py2.py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 6.6 MB/s
# Collecting tableschema<2.0a,>=1.5.2
#   Downloading tableschema-1.20.2-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 5.2 MB/s
# Requirement already satisfied: six<2.0a,>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld) (1.15.0)
# Collecting tabulator>=1.22.0
#   Downloading tabulator-1.53.5-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 420 kB/s
# Collecting unicodecsv>=0.14
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.7/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (4.3.3)
# Collecting jsonpointer>=1.10
#   Downloading jsonpointer-2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: chardet>=3.0 in /usr/local/lib/python3.7/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (3.0.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (21.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (4.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (3.10.0.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0a,>=2.0.0->datadotworld) (2.10)
# Collecting rfc3986>=1.1.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: cached-property>=1.5 in /usr/local/lib/python3.7/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld) (1.5.2)
# Collecting isodate>=0.5.4
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 402 kB/s
# Collecting jsonlines>=1.1
#   Downloading jsonlines-3.0.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld) (1.4.32)
# Collecting ijson>=3.0.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 46.2 MB/s
# Collecting linear-tsv>=1.0
#   Downloading linear-tsv-1.1.0.tar.gz (9.6 kB)
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld) (1.1.0)
# Collecting boto3>=1.9
#   Downloading boto3-1.21.30-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 46.1 MB/s
# Requirement already satisfied: openpyxl>=2.6 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld) (3.0.9)
# Collecting botocore<1.25.0,>=1.24.30
#   Downloading botocore-1.24.30-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 43.9 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.7 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting urllib3<2.0a,>=1.15
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 51.7 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=0.9.6->tabulator>=1.22.0->datadotworld) (1.1.2)
# Building wheels for collected packages: linear-tsv, unicodecsv
#   Building wheel for linear-tsv (setup.py) ... done
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-py3-none-any.whl size=7400 sha256=71bd6ef02d78077a81cc54a344d2a8d5b835debccb5e1eebba8cf1904a5eadc8
#   Stored in directory: /root/.cache/pip/wheels/dd/0a/62/49ee84fab92057fb3e303fb1a59e75ccac6899b417f441305a
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10768 sha256=c7d2bd5f9efd063c25b3f335043c61bb2d110a7f10dfc5b69550b360d2befe82
#   Stored in directory: /root/.cache/pip/wheels/1a/f4/8a/a5024fb77b32ed369e5c409081e5f00fbe3b92fdad653f6e69
# Successfully built linear-tsv unicodecsv
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, unicodecsv, linear-tsv, jsonlines, ijson, click, boto3, tabulator, rfc3986, isodate, tableschema, jsonpointer, datapackage, configparser, datadotworld
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pip-tools 6.2.0 requires click>=7, but you have click 6.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed boto3-1.21.30 botocore-1.24.30 click-6.7 configparser-3.8.1 datadotworld-1.8.0 datapackage-1.15.2 ijson-3.1.4 isodate-0.6.1 jmespath-1.0.0 jsonlines-3.0.0 jsonpointer-2.2 linear-tsv-1.1.0 rfc3986-2.0.0 s3transfer-0.5.2 tableschema-1.20.2 tabulator-1.53.5 unicodecsv-0.14.1 urllib3-1.25.11
# Requirement already satisfied: datadotworld[pandas] in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: configparser<4.0a,>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (3.8.1)
# Requirement already satisfied: python-dateutil<3.0a,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (2.8.2)
# Requirement already satisfied: six<2.0a,>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (1.15.0)
# Requirement already satisfied: datapackage<2.0a,>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (1.15.2)
# Requirement already satisfied: tabulator>=1.22.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (1.53.5)
# Requirement already satisfied: tableschema<2.0a,>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (1.20.2)
# Requirement already satisfied: click<7.0a,>=6.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (6.7)
# Requirement already satisfied: urllib3<2.0a,>=1.15 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (1.25.11)
# Requirement already satisfied: requests<3.0a,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (2.23.0)
# Requirement already satisfied: certifi>=2017.04.17 in /usr/local/lib/python3.7/dist-packages (from datadotworld[pandas]) (2021.10.8)
# Collecting numpy<=1.16.4
#   Downloading numpy-1.16.4-cp37-cp37m-manylinux1_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 218 kB/s
# Collecting pandas<0.25
#   Downloading pandas-0.24.2-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 18.9 MB/s
# Requirement already satisfied: unicodecsv>=0.14 in /usr/local/lib/python3.7/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (0.14.1)
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.7/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (4.3.3)
# Requirement already satisfied: chardet>=3.0 in /usr/local/lib/python3.7/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (3.0.4)
# Requirement already satisfied: jsonpointer>=1.10 in /usr/local/lib/python3.7/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (2.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (0.18.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (3.10.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (4.11.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (21.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (3.7.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.7/dist-packages (from pandas<0.25->datadotworld[pandas]) (2018.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0a,>=2.0.0->datadotworld[pandas]) (2.10)
# Requirement already satisfied: isodate>=0.5.4 in /usr/local/lib/python3.7/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (0.6.1)
# Requirement already satisfied: cached-property>=1.5 in /usr/local/lib/python3.7/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (1.5.2)
# Requirement already satisfied: rfc3986>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (2.0.0)
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.1.0)
# Requirement already satisfied: linear-tsv>=1.0 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.1.0)
# Requirement already satisfied: openpyxl>=2.6 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (3.0.9)
# Requirement already satisfied: ijson>=3.0.3 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (3.1.4)
# Requirement already satisfied: jsonlines>=1.1 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (3.0.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.4.32)
# Requirement already satisfied: boto3>=1.9 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.21.30)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (1.0.0)
# Requirement already satisfied: botocore<1.25.0,>=1.24.30 in /usr/local/lib/python3.7/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (1.24.30)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (0.5.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld[pandas]) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=0.9.6->tabulator>=1.22.0->datadotworld[pandas]) (1.1.2)
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# xarray 0.18.2 requires numpy>=1.17, but you have numpy 1.16.4 which is incompatible.
# xarray 0.18.2 requires pandas>=1.0, but you have pandas 0.24.2 which is incompatible.
# tensorflow 2.8.0 requires numpy>=1.20, but you have numpy 1.16.4 which is incompatible.
# tables 3.7.0 requires numpy>=1.19.0, but you have numpy 1.16.4 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.16.4 which is incompatible.
# pywavelets 1.3.0 requires numpy>=1.17.3, but you have numpy 1.16.4 which is incompatible.
# pyerfa 2.0.0.1 requires numpy>=1.17, but you have numpy 1.16.4 which is incompatible.
# pyarrow 6.0.1 requires numpy>=1.16.6, but you have numpy 1.16.4 which is incompatible.
# plotnine 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# mizani 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# kapre 0.3.7 requires numpy>=1.18.5, but you have numpy 1.16.4 which is incompatible.
# jaxlib 0.3.2+cuda11.cudnn805 requires numpy>=1.19, but you have numpy 1.16.4 which is incompatible.
# jax 0.3.4 requires numpy>=1.19, but you have numpy 1.16.4 which is incompatible.
# google-colab 1.0.0 requires pandas>=1.1.0; python_version >= "3.0", but you have pandas 0.24.2 which is incompatible.
# fbprophet 0.7.1 requires pandas>=1.0.4, but you have pandas 0.24.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# astropy 4.3.1 requires numpy>=1.17, but you have numpy 1.16.4 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.16.4 pandas-0.24.2

# %%
# !dw configure
# Out:
# API token (obtained at: https://data.world/settings/advanced): eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50OmV2bmlldyIsImlzcyI6ImFnZW50OmV2bmlldzo6MmIyMjAxYWYtNDgzMi00NDc0LWJmNDUtYzRhN2FiZDQ5YjVhIiwiaWF0IjoxNjQ4NzE1NTkzLCJyb2xlIjpbInVzZXJfYXBpX3JlYWQiLCJ1c2VyX2FwaV93cml0ZSJdLCJnZW5lcmFsLXB1cnBvc2UiOnRydWUsInNhbWwiOnt9fQ.tCb2LG-q9QhJgkyilrEpP-3Zi_Z9jIqIhp1xCuMIu5-ymWJxepefS6v4zNq7YcJUxgIppziK6W-C_-IPO71_rA

# %%
from google.colab import drive
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/dw_matrix'
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# !mkdir data

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
data.dataframes
# Out:
# LazyLoadedDict({'7004_1': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df = data.dataframes['7004_1']
df.shape
# Out:
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id asins        brand  \
# 7276   AVpfVyB3ilAPnD_xZ-ZV   NaN         Nike
# 6542   AVpe6HcGLJeJML43yCYa   NaN    Florsheim
# 17293  AVpfSu_hilAPnD_xY_S-   NaN  New Balance
# 12015  AVpflpAVilAPnD_xeiTC   NaN     Woolrich
# 15937  AVpfaOMOLJeJML438u5K   NaN        Smoky
#
#                                               categories  \
# 7276          All Men's Shoes,Shoes,Men's Shoes,Clothing
# 6542        Men's Dress Shoes,Shoes,Men's Shoes,Clothing
# 17293  All Men's Shoes,Shoes,Men's Shoes,Clothing,Sne...
# 12015         All Men's Shoes,Shoes,Men's Shoes,Clothing
# 15937             Men's Boots,Shoes,Men's Shoes,Clothing
#
#                        colors  count             dateadded  \
# 7276                      NaN    NaN  2016-11-11T09:48:00Z
# 6542                    Brown    NaN  2017-01-27T01:30:30Z
# 17293  Multicolor,SilverGreen    NaN  2015-08-14T18:22:58Z
# 12015                   Beige    NaN  2017-01-27T01:20:24Z
# 15937                   Brown    NaN  2017-01-27T01:30:16Z
#
#                 dateupdated  \
# 7276   2016-11-11T09:48:00Z
# 6542   2017-01-27T01:30:30Z
# 17293  2017-01-09T20:23:44Z
# 12015  2017-01-27T01:20:24Z
# 15937  2017-01-27T01:30:16Z
#
#                                             descriptions dimension  ...  \
# 7276   [{"dateSeen":["2016-11-11T09:48:00Z"],"sourceU...       NaN  ...
# 6542   [{"dateSeen":["2017-01-27T01:30:30Z"],"sourceU...       NaN  ...
# 17293  [{"dateSeen":["2017-01-09T20:23:44Z"],"sourceU...       NaN  ...
# 12015  [{"dateSeen":["2017-01-27T01:20:24Z"],"sourceU...       NaN  ...
# 15937  [{"dateSeen":["2017-01-27T01:30:16Z"],"sourceU...       NaN  ...
#
#        prices_warranty quantities  reviews  \
# 7276               NaN        NaN      NaN
# 6542               NaN        NaN      NaN
# 17293              NaN        NaN      NaN
# 12015              NaN        NaN      NaN
# 15937              NaN        NaN      NaN
#
#                                           sizes  \
# 7276                                        NaN
# 6542                                        NaN
# 17293  11.5,12,7D,12D,11D,10D,8D,13D,9D,15D,14D
# 12015                                         6
# 15937                                       NaN
#
#                                                     skus  \
# 7276                                                 NaN
# 6542                                                 NaN
# 17293  [{"sourceURLs":["http://www.shoes.com/mens-new...
# 12015                                                NaN
# 15937                                                NaN
#
#                                               sourceurls           upc  vin  \
# 7276   https://www.walmart.com/ip/Nike-Men-s-Air-Max-...  826220602295  NaN
# 6542   https://www.walmart.com/ip/Florsheim-Mens-Benn...  023938013171  NaN
# 17293  https://www.walmart.com/ip/New-Balance-MXC90-M...  739980051145  NaN
# 12015  https://www.walmart.com/ip/Woolrich-Beebe-Wome...  840433115502  NaN
# 15937  https://www.walmart.com/ip/Smoky-Mountain-Dist...  840955005398  NaN
#
#       websiteids weight
# 7276         NaN    NaN
# 6542         NaN    NaN
# 17293        NaN    NaN
# 12015        NaN    NaN
# 15937        NaN    NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# UnbeatableSale.com, Inc. - Walmart.com                    3
# PalmBeach Jewelry - Walmart.com                           3
# new                                                       3
# New with box                                              3
# Wholesale Costume and Party Supplies - Walmart.com        2
# Shoes.com                                                 1
# SHOEBACCA LTD. - Walmart.com                              1
# New without tags                                          1
# Name: prices_currency, dtype: int64

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# PalmBeach Jewelry - Walmart.com                       0.000155
# new                                                   0.000155
# New with box                                          0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# Shoes.com                                             0.000052
# SHOEBACCA LTD. - Walmart.com                          0.000052
# New without tags                                      0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd = df[ df.prices_currency == 'USD' ].copy()

df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd.prices_amountmin.head()
# Out:
# 0    39.89
# 1    51.99
# 2    40.02
# 3    50.31
# 4    46.26
# Name: prices_amountmin, dtype: object

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
np.percentile( df_usd['prices_amountmin'], 99)
# Out:
# 895.0

# %%
filter_max = np.percentile( df_usd['prices_amountmin'], 99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[ df_usd['prices_amountmin'] < filter_max ]

df_usd_filter.prices_amountmin.hist()

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
ls Matrix1
# Out:
# day3.ipynb

# %%
# !git add Matrix1/day3.ipynb
